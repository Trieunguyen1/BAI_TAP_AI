# %% [markdown]
# <a href="https://colab.research.google.com/github/Trieunguyen1/BAI_TAP_AI/blob/main/nhan_dang_11_loai_tien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
training_data=train_datagen.flow_from_directory('/content/drive/MyDrive/11_loai_tien/train',
                                               target_size=(150,150),
                                               batch_size=32,
                                               class_mode ='categorical')
validation_data=train_datagen.flow_from_directory('/content/drive/MyDrive/11_loai_tien/test',
                                               target_size=(150,150),
                                               batch_size=32,
                                               class_mode ='categorical')
# Out:
# Found 204 images belonging to 11 classes.
# Found 73 images belonging to 11 classes.

# %%
model=Sequential()
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer = 'he_uniform'))
#model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 150, 150, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        36896
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 43808)             0
#
#  dense (Dense)               (None, 128)               5607552
#
#  dense_1 (Dense)             (None, 11)                1419
#
# ...
# Total params: 5,649,451
# Trainable params: 5,649,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
callbacks=[EarlyStopping(monitor='val_loss',patience=100)]
history=model.fit(training_data,
                  steps_per_epoch=len(training_data),
                  batch_size = 64,
                  epochs=100,
                  validation_data=validation_data,
                  validation_steps=len(validation_data),
                  callbacks=callbacks,
                  verbose = 1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 103s 14s/step - loss: 9.4675 - accuracy: 0.0833 - val_loss: 2.3982 - val_accuracy: 0.0548
# Epoch 2/100
# 7/7 [==============================] - 36s 6s/step - loss: 2.3976 - accuracy: 0.0686 - val_loss: 2.3981 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 7/7 [==============================] - 40s 6s/step - loss: 2.3969 - accuracy: 0.0980 - val_loss: 2.3974 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 7/7 [==============================] - 36s 5s/step - loss: 2.3961 - accuracy: 0.0833 - val_loss: 2.3967 - val_accuracy: 0.0548
# Epoch 5/100
# 7/7 [==============================] - 36s 5s/step - loss: 2.3952 - accuracy: 0.0784 - val_loss: 2.3957 - val_accuracy: 0.1370
# Epoch 6/100
# 7/7 [==============================] - 36s 6s/step - loss: 2.3942 - accuracy: 0.0931 - val_loss: 2.3944 - val_accuracy: 0.0548
# Epoch 7/100
# ...

# %%
#đánh giá chất lượng của mô hình và vẽ lại
score = model.evaluate(validation_data,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('Độ chính xác kiểm tra là: ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# Sai số kiểm tra là:  0.08052436262369156
# Độ chính xác kiểm tra là:  0.9726027250289917
# <function matplotlib.pyplot.show>

# %%
model.save('model_11_To_Tien_VN.h5')
model=load_model('model_11_To_Tien_VN.h5')

# %%
img=load_img("/content/drive/MyDrive/11_loai_tien/prediction/20000.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='1000'
if round(result[0][1])==1:
  prediction='10000'
if round(result[0][2])==1:
  prediction='100000'
if round(result[0][3])==1:
  prediction='200'
if round(result[0][4])==1:
  prediction='2000'
if round(result[0][5])==1:
  prediction='20000'
if round(result[0][6])==1:
  prediction='200000'
if round(result[0][7])==1:
  prediction='500'
if round(result[0][8])==1:
  prediction='5000'
if round(result[0][9])==1:
  prediction='50000'
if round(result[0][10])==1:
  prediction='500000'
print(prediction)
# Out:
# 20000

# %%
img=load_img("/content/drive/MyDrive/11_loai_tien/prediction/500.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='1000'
if round(result[0][1])==1:
  prediction='10000'
if round(result[0][2])==1:
  prediction='100000'
if round(result[0][3])==1:
  prediction='200'
if round(result[0][4])==1:
  prediction='2000'
if round(result[0][5])==1:
  prediction='20000'
if round(result[0][6])==1:
  prediction='200000'
if round(result[0][7])==1:
  prediction='500'
if round(result[0][8])==1:
  prediction='5000'
if round(result[0][9])==1:
  prediction='50000'
if round(result[0][10])==1:
  prediction='500000'
print(prediction)
# Out:
# 500

# %%
img=load_img("/content/drive/MyDrive/11_loai_tien/prediction/500000.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='1000'
if round(result[0][1])==1:
  prediction='10000'
if round(result[0][2])==1:
  prediction='100000'
if round(result[0][3])==1:
  prediction='200'
if round(result[0][4])==1:
  prediction='2000'
if round(result[0][5])==1:
  prediction='20000'
if round(result[0][6])==1:
  prediction='200000'
if round(result[0][7])==1:
  prediction='500'
if round(result[0][8])==1:
  prediction='5000'
if round(result[0][9])==1:
  prediction='50000'
if round(result[0][10])==1:
  prediction='500000'
print(prediction)
# Out:
# 500000

# %%
img=load_img("/content/drive/MyDrive/11_loai_tien/prediction/100000.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='1000'
if round(result[0][1])==1:
  prediction='10000'
if round(result[0][2])==1:
  prediction='100000'
if round(result[0][3])==1:
  prediction='200'
if round(result[0][4])==1:
  prediction='2000'
if round(result[0][5])==1:
  prediction='20000'
if round(result[0][6])==1:
  prediction='200000'
if round(result[0][7])==1:
  prediction='500'
if round(result[0][8])==1:
  prediction='5000'
if round(result[0][9])==1:
  prediction='50000'
if round(result[0][10])==1:
  prediction='500000'
print(prediction)
# Out:
# 100000

# %%
img=load_img("/content/drive/MyDrive/11_loai_tien/prediction/200000.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='1000'
if round(result[0][1])==1:
  prediction='10000'
if round(result[0][2])==1:
  prediction='100000'
if round(result[0][3])==1:
  prediction='200'
if round(result[0][4])==1:
  prediction='2000'
if round(result[0][5])==1:
  prediction='20000'
if round(result[0][6])==1:
  prediction='200000'
if round(result[0][7])==1:
  prediction='500'
if round(result[0][8])==1:
  prediction='5000'
if round(result[0][9])==1:
  prediction='50000'
if round(result[0][10])==1:
  prediction='500000'
print(prediction)
# Out:
# 200000
